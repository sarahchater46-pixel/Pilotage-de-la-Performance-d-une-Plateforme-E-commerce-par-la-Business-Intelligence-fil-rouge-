# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Lecture du dataset (Remplace par ton fichier)
df = pd.read_csv("data fil rouge.csv")

print("========== 1. DIAGNOSTIC GLOBAL ==========")
# Dimensions
print(f"Structure du dataset : {df.shape[0]} lignes et {df.shape[1]} colonnes.\n")

# Types de colonnes et mémoire
print("--- Types de données ---")
print(df.info())

# Aperçu des données
print("\n--- Aperçu des 5 premières lignes ---")
print(df.head())
# Out:
# ========== 1. DIAGNOSTIC GLOBAL ==========
# Structure du dataset : 80000 lignes et 23 colonnes.
#
# --- Types de données ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID_Commande       80000 non-null  object
#  1   Date              80000 non-null  object
#  2   Client            80000 non-null  object
#  3   Genre             80000 non-null  object
#  4   Age               80000 non-null  int64
#  5   Type_Client       80000 non-null  object
#  6   Ville             80000 non-null  object
#  7   Indice_HCP        80000 non-null  int64
#  8   Categorie         80000 non-null  object
#  9   Produit           80000 non-null  object
#  10  Quantite          80000 non-null  int64
#  11  Ventes_Brutes     80000 non-null  int64
#  12  Cout_Produit      80000 non-null  float64
# ...

# %%
df.head()          # 5 premières lignes
# Out:
#   ID_Commande        Date   Client  Genre  Age Type_Client      Ville  \
# 0     M-10000  2024-03-17     Sami  Homme   52      Fidèle  Marrakech
# 1     M-10001  2023-11-22     Adil  Homme   47      Fidèle    Kénitra
# 2     M-10002  2023-05-31    Lamia  Femme   60      Fidèle     Agadir
# 3     M-10003  2023-02-07     Saad  Homme   44     Nouveau  Marrakech
# 4     M-10004  2023-01-16  Keltoum  Femme   26      Fidèle     Tanger
#
#    Indice_HCP    Categorie             Produit  ...            Mode_Paiement  \
# 0          80  Electronics         Samsung S23  ...  Paiement à la livraison
# 1          65    Furniture          Pouf Salon  ...           Carte Bancaire
# 2          70    Furniture    Chaise de bureau  ...  Paiement à la livraison
# 3          80     Clothing        Pyjama Satin  ...           Carte Bancaire
# 4          75  Accessories  Lunettes de soleil  ...  Paiement à la livraison
#
#    Canal_Marketing    CAC Impressions Clics     Transporteur  \
# ...

# %%
df.info()          # types et valeurs manquantes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID_Commande       80000 non-null  object
#  1   Date              80000 non-null  object
#  2   Client            80000 non-null  object
#  3   Genre             80000 non-null  object
#  4   Age               80000 non-null  int64
#  5   Type_Client       80000 non-null  object
#  6   Ville             80000 non-null  object
#  7   Indice_HCP        80000 non-null  int64
#  8   Categorie         80000 non-null  object
#  9   Produit           80000 non-null  object
#  10  Quantite          80000 non-null  int64
#  11  Ventes_Brutes     80000 non-null  int64
#  12  Cout_Produit      80000 non-null  float64
#  13  Mode_Paiement     80000 non-null  object
#  14  Canal_Marketing   80000 non-null  object
#  15  CAC               80000 non-null  float64
# ...

# %%
df.shape           # lignes et colonnes
df.columns         # noms des colonnes
# Out:
# Index(['ID_Commande', 'Date', 'Client', 'Genre', 'Age', 'Type_Client', 'Ville',
#        'Indice_HCP', 'Categorie', 'Produit', 'Quantite', 'Ventes_Brutes',
#        'Cout_Produit', 'Mode_Paiement', 'Canal_Marketing', 'CAC',
#        'Impressions', 'Clics', 'Transporteur', 'Note_Google_Maps',
#        'Statut_Livraison', 'Motif_Retour', 'Profit_Net'],
#       dtype='object')

# %%
df.describe()      # statistiques descriptives
# Out:
#                 Age    Indice_HCP      Quantite  Ventes_Brutes  Cout_Produit  \
# count  80000.000000  80000.000000  80000.000000   80000.000000  80000.000000
# mean      43.994737     71.676625      1.999950    2162.048313   1296.644039
# std       14.134166     13.610428      0.815388    2229.010949   1339.283433
# min       20.000000     50.000000      1.000000      50.000000     27.760000
# 25%       32.000000     60.000000      1.000000     579.000000    346.635000
# 50%       44.000000     75.000000      2.000000    1068.000000    637.810000
# 75%       56.000000     85.000000      3.000000    3385.000000   2030.285000
# max       68.000000     95.000000      3.000000    9000.000000   5838.240000
#
#                 CAC   Impressions         Clics  Note_Google_Maps  \
# count  80000.000000  80000.000000  80000.000000      80000.000000
# mean      26.889386    549.899900     11.865625          3.596406
# std       15.085216    260.272734     11.700152          0.967572
# ...

# %% [markdown]
# Le persona principal de ce store est un adulte actif âgé d'environ 44 ans, disposant d'un pouvoir d'achat moyen à élevé et recherchant avant tout la qualité et la fiabilité dans ses achats. Il effectue généralement des commandes de deux produits et dépense en moyenne plus de 2 000 MAD par transaction. Avant de prendre une décision d'achat, il est sensible aux publicités en ligne, consulte les avis Google et accorde une grande importance à la réputation de l'enseigne. Ce client est prêt à payer davantage pour un bon rapport qualité-prix, un service client efficace et une expérience d'achat rassurante. Fidèle lorsqu'il est satisfait, il représente une source importante de revenus et de profit pour l'entreprise, ce qui en fait une cible prioritaire pour les actions de fidélisation et les offres personnalisées

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# Vérification des valeurs aberrantes

# %%
import seaborn as sns

sns.boxplot(data=df, x="Profit_Net")
# Out:
# <Axes: xlabel='Profit_Net'>

# %% [markdown]
# Phase 3 — Analyse descriptive

# %% [markdown]
# Variables numériques

# %%
df["Profit_Net"].describe()
# Out:
# count    80000.000000
# mean       681.103871
# std        881.557111
# min       -159.440000
# 25%         71.707500
# 50%        293.255000
# 75%       1087.600000
# max       3996.420000
# Name: Profit_Net, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.hist(df["Profit_Net"])
plt.show()

# %% [markdown]
# Variables catégorielles

# %%
df["Canal_Marketing"].value_counts()
# Out:
# Canal_Marketing
# Google Search    20352
# Meta (FB/IG)     20014
# TikTok Ads       19844
# SEO/Direct       19790
# Name: count, dtype: int64

# %%
df["Canal_Marketing"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Canal_Marketing'>

# %% [markdown]
# Phase 4 — Analyse bivariée (Relations entre variables)

# %% [markdown]
# Marketing → Vente

# %% [markdown]
# "Quel canal marketing génère le plus de revenu ?"

# %%
df.groupby("Canal_Marketing")["Profit_Net"].sum()
# Out:
# Canal_Marketing
# Google Search    13581620.65
# Meta (FB/IG)     13520442.80
# SEO/Direct       13871354.46
# TikTok Ads       13514891.81
# Name: Profit_Net, dtype: float64

# %%
sns.barplot(
x="Canal_Marketing",
y="Profit_Net",
data=df
)
# Out:
# <Axes: xlabel='Canal_Marketing', ylabel='Profit_Net'>

# %% [markdown]
# Client → Achat

# %% [markdown]
# "Quel segment client dépense le plus ?"

# %%
df.groupby("Categorie")["Profit_Net"].mean()
# Out:
# Categorie
# Accessories     148.840426
# Clothing        147.317303
# Electronics    1604.439432
# Furniture       821.674730
# Name: Profit_Net, dtype: float64

# %%
sns.barplot(
x="Categorie",
y="Profit_Net",
data=df
)
# Out:
# <Axes: xlabel='Categorie', ylabel='Profit_Net'>
